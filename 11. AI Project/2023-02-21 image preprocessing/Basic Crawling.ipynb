# %% [markdown]
# # Basic Crawling 및 이미지 다운로드

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import os
import urllib.request
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### 폴더 생성

# %%
def create_folder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSError:
        print("error : Creating directory ... " + directory)

# %% [markdown]
# # 키워드 변경 필요!!!!

# %%
keywords = "'military uav GJ-2GJ-11Dark Sword'" # <-이거 변경 안하면 망함 ㅇㅇ 
create_folder('./'+keywords+'_img_download')

# %% [markdown]
# #### chromedriver실행

# %%
# 크롬창이 함수를 종료할 때마다 닫히지 않게 해주는 옵션
options = webdriver.ChromeOptions()
options.add_experimental_option("detach", True)


chromedriver_path = "./chromedriver.exe"

driver = webdriver.Chrome(chromedriver_path, options=options)
driver.implicitly_wait(3)

# %% [markdown]
# ### 키워드 입력 및 selenium 실행

# %%
driver.get("https://www.google.co.kr/imghp?h1=ko")
position = driver.get_window_position()
x = position.get('x')
y = position.get('y')
print("x: "+ str(x) + "y: " + str(y))
# Out:
# x: 9y: 9

# %%
driver.maximize_window()
# driver.fullscreen_window()

# %% [markdown]
# - input -> /html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input
# - button -> /html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button

# %%
keyword = driver.find_element_by_xpath(
    '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input')
keyword.send_keys(keywords)
keyword.send_keys(Keys.RETURN)

# %% [markdown]
# ### 스크롤 내리기

# %%
print('Scroll Down .......')
elem = driver.find_element_by_tag_name('body')
for i in range(100):
    elem.send_keys(Keys.PAGE_DOWN)
    time.sleep(0.2)

try:
    # //*[@id="islmp"]/div/div/div/div[2]/div[1]/div[2]/div[2]/input
    driver.find_element_by_xpath(
        '//*[@id="islmp"]/div/div/div/div[2]/div[1]/div[2]/div[2]/input').click()
    for i in range(100):
        elem.send_keys(Keys.PAGE_DOWN)
        time.sleep(0.2)
except:
    pass
# Out:
# Scroll Down .......

# %% [markdown]
# ### 이미지 개수 파악
#
# - 구글 이미지 검색 결과의 각 썸네일 이미지 class name은 img.rg_i.Q4LuWd이다.
#
# - 따라서 driver.find_elements_by_css_selector를 통해 해당 class name을 가진 모든 요소를 images로 불러온다.
#
# - 또한, 구조를 살펴보면 각 이미지는 src에 해당 이미지 링크를 가지고 있다. get_attribute를 통해 links라는 빈 리스트에 각 link들을 넣어주었다.

# %%
links = []
images = driver.find_elements_by_css_selector("img.rg_i.Q4LuWd")

for image in images:
    if image.get_attribute('src') != None:
        links.append(image.get_attribute('src'))

print(keywords + " img found: ", len(links))
time.sleep(2)
# Out:
# 'military uav GJ-2GJ-11Dark Sword' img found:  22

# %% [markdown]
# ### 데이터 다운로드
#
# - links에 들어있는 link를 urllib.request를 통해 하나씩 요청하고, 해당 이미지들을 '키워드_number'의 형태로 위에서 만들어준 폴더에 저장하도록 한다.

# %%
for index, i in enumerate(links):
    url = i
    start = time.time()
    urllib.request.urlretrieve(url, './' + keywords + "_img_download/" + keywords + "_" + str(index) + ".jpg")
    print(str(index) + "/" + str(len(links)) + " " + keywords +
          " Downloaded ------ : ", str(time.time() - start)[:5] + 'sec')

print(keywords + "Download Finished !!")
# Out:
# 0/22 'military uav GJ-2GJ-11Dark Sword' Downloaded ------ :  0.001sec
# 1/22 'military uav GJ-2GJ-11Dark Sword' Downloaded ------ :  0.002sec
# 2/22 'military uav GJ-2GJ-11Dark Sword' Downloaded ------ :  0.001sec
# 3/22 'military uav GJ-2GJ-11Dark Sword' Downloaded ------ :  0.001sec
# 4/22 'military uav GJ-2GJ-11Dark Sword' Downloaded ------ :  0.001sec
# 5/22 'military uav GJ-2GJ-11Dark Sword' Downloaded ------ :  0.001sec
# 6/22 'military uav GJ-2GJ-11Dark Sword' Downloaded ------ :  0.001sec
# 7/22 'military uav GJ-2GJ-11Dark Sword' Downloaded ------ :  0.000sec
# 8/22 'military uav GJ-2GJ-11Dark Sword' Downloaded ------ :  0.000sec
# 9/22 'military uav GJ-2GJ-11Dark Sword' Downloaded ------ :  0.001sec
# 10/22 'military uav GJ-2GJ-11Dark Sword' Downloaded ------ :  0.000sec
# 11/22 'military uav GJ-2GJ-11Dark Sword' Downloaded ------ :  0.000sec
# 12/22 'military uav GJ-2GJ-11Dark Sword' Downloaded ------ :  0.000sec
# 13/22 'military uav GJ-2GJ-11Dark Sword' Downloaded ------ :  0.001sec
# 14/22 'military uav GJ-2GJ-11Dark Sword' Downloaded ------ :  0.000sec
# 15/22 'military uav GJ-2GJ-11Dark Sword' Downloaded ------ :  0.0sec
# 16/22 'military uav GJ-2GJ-11Dark Sword' Downloaded ------ :  0.002sec
# 17/22 'military uav GJ-2GJ-11Dark Sword' Downloaded ------ :  0.001sec
# 18/22 'military uav GJ-2GJ-11Dark Sword' Downloaded ------ :  0.001sec
# 19/22 'military uav GJ-2GJ-11Dark Sword' Downloaded ------ :  0.000sec
# 20/22 'military uav GJ-2GJ-11Dark Sword' Downloaded ------ :  0.201sec
# 21/22 'military uav GJ-2GJ-11Dark Sword' Downloaded ------ :  0.271sec
# 'military uav GJ-2GJ-11Dark Sword'Download Finished !!

# %%
driver.quit()
